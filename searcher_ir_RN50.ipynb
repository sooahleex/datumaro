# %%
# Copyright (C) 2022 Intel Corporationworkbench.action.openLargeOutput
#
# SPDX-License-Identifier: MIT

import os
import datumaro as dm
import time

from datumaro.components.searcher import Searcher
from datumaro.components.visualizer import Visualizer

# %% [markdown]
# ## onnx inference

# %%
start_time = time.time()
onnx_dataset = dm.Dataset.import_from("coco_dataset", format='coco_instances', save_hash=True, hash_mode="onnx")
print(f'setting dataset time for {len(onnx_dataset)} items: ', time.time()-start_time)
# Out:
# WARNING:root:File 'coco_dataset/annotations/captions_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# WARNING:root:File 'coco_dataset/annotations/person_keypoints_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# WARNING:root:File 'coco_dataset/annotations/panoptic_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# 5000it [19:05,  4.36it/s]
# setting dataset time for 5000 items:  1147.5492675304413

# %%
visualizer = Visualizer(onnx_dataset, figsize=(12, 12), alpha=0)
searcher = Searcher(onnx_dataset)

# %% [markdown]
# ### Image query search

# %%
for i, item in enumerate(onnx_dataset):
    if i==7:
        query = item

# %%
topk_list = searcher.search_topk(query, topk=15)
results = [query] + topk_list[1:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ### Text query search

# %%
topk_list = searcher.search_topk('motorcycle', topk=15)
subset_list = []
id_list =[]
for result in topk_list:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4175/910364290.py in <module>
# ----> 1 topk_list = searcher.search_topk('motorcycle', topk=15)
#       2 subset_list = []
#       3 id_list =[]
#       4 for result in topk_list:
#       5     subset_list.append(result.subset)
#
# ~/workspace/datumaro_sa/datumaro/components/searcher.py in search_topk(self, query, topk)
#     132         retrieval_keys = np.stack(self._retrieval_keys, axis=0)
#     133
# --> 134         logits = calculate_hamming(query_key, retrieval_keys)
#     135         ind = np.argsort(logits)
#     136
#
# ~/workspace/datumaro_sa/datumaro/components/searcher.py in calculate_hamming(B1, B2)
#      20     """
#      21     q = B2.shape[1]  # max inner product value
# ---> 22     distH = 0.5 * (q - B1 @ B2.transpose())
#      23     return distH
#      24
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1024 is different from 512)

# %% [markdown]
# ### Image query list search

# %%
query_list = []
for i, item in enumerate(dataset):
    if i in [7, 23, 31]: # 7-motorcycle, 23-bus, 26-giraffe, 31-train
        query_list.append(item)

# %%
topk_list = searcher.search_topk(query_list, topk=15)
results = topk_list[:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ### Text query list search

# %%
topk_list = searcher.search_topk(['motorcycle', 'bus', 'train'], topk=15)
results = topk_list[:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %%
topk_list = searcher.search_topk(['motorcycle and bus and train'], topk=15)
results = topk_list[:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ## OV IR inference

# %%
start_time = time.time()
ir_dataset = dm.Dataset.import_from("coco_dataset", format='coco_instances', save_hash=True, hash_mode="ir")
print(f'setting dataset time for {len(ir_dataset)} items: ', time.time()-start_time)
# Out:
# WARNING:root:File 'coco_dataset/annotations/captions_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# WARNING:root:File 'coco_dataset/annotations/person_keypoints_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# WARNING:root:File 'coco_dataset/annotations/panoptic_val2017.json' was skipped, could't match this file with any of these tasks: coco_instances
# 5000it [03:06, 26.76it/s]
# setting dataset time for 5000 items:  188.60648727416992

# %%
visualizer = Visualizer(ir_dataset, figsize=(12, 12), alpha=0)
searcher = Searcher(ir_dataset)

# %% [markdown]
# ### Image query search

# %%
for i, item in enumerate(ir_dataset):
    if i==7:
        query = item

# %%
topk_list = searcher.search_topk(query, topk=15)
results = [query] + topk_list[1:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ### Text query search

# %%
topk_list = searcher.search_topk('motorcycle', topk=15)
subset_list = []
id_list =[]
for result in topk_list:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ### Image query list search

# %%
query_list = []
for i, item in enumerate(ir_dataset):
    if i in [7, 23, 31]: # 7-motorcycle, 23-bus, 26-giraffe, 31-train
        query_list.append(item)

# %%
topk_list = searcher.search_topk(query_list, topk=15)
results = topk_list[:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ### Text query list search

# %%
topk_list = searcher.search_topk(['motorcycle', 'bus', 'train'], topk=15)
results = topk_list[:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %%
topk_list = searcher.search_topk(['motorcycle and bus and train'], topk=15)
results = topk_list[:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ## OV IR inference w/ INT8 model

# %%
start_time = time.time()
ir_in8_dataset = dm.Dataset.import_from("coco_dataset", format='coco_instances', save_hash=True, hash_mode="ir_int8")
print(f'setting dataset time for {len(ir_in8_dataset)} items: ', time.time()-start_time)

# %%
visualizer = Visualizer(ir_in8_dataset, figsize=(12, 12), alpha=0)
searcher = Searcher(ir_in8_dataset)

# %% [markdown]
# ### Image query search

# %%
for i, item in enumerate(ir_in8_dataset):
    if i==7:
        query = item

# %%
topk_list = searcher.search_topk(query, topk=15)
results = [query] + topk_list[1:]
subset_list = []
id_list =[]
for result in results:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()

# %% [markdown]
# ### Text query search

# %%
topk_list = searcher.search_topk('motorcycle', topk=15)
subset_list = []
id_list =[]
for result in topk_list:
    subset_list.append(result.subset)
    id_list.append(result.id)
fig = visualizer.vis_gallery(id_list[:12], subset_list[:12], (None, None))
fig.show()
